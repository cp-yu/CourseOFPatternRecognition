# %%
import os
import io
import numpy as np
import cv2

# 以下代码用于将faceDS文件中的文件名和标签写入txt文件中

f = open( 'C:\\Users\\86139\\a\\a\\face\\faceDS', 'r',encoding = 'utf-8' )


with open('./DS.txt', 'w') as t:
    for line in f.readlines():
        lineArr = line.strip(' ').split(' ')  # strip 去除首尾的指定字符；
        # lineArr = lineArr.remove('(_sex')

        # num = np.shape(lineArr)[0]
        if len(lineArr) == 3:
            pass
        else:
            lineArr = lineArr  # [0]代表文件名，[1]代表(_sex，[2]空，[3]代表female)或者male)
            print(lineArr)
            if lineArr[3] == 'female)':
                t.write(lineArr[0] + ".jpg " +'0' + "\n")
            if lineArr[3] == 'male)':
                t.write(lineArr[0] + ".jpg " +'1' + "\n")

        # f.close()




f.close()
# Out:
# ['3223', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'(hat", '))\n']
# ['3224', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3225', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3226', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3227', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3228', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3229', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3230', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3231', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(hat", '))\n']
# ['3232', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3233', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3234', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3235', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3236', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3237', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3238', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3239', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3240', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3241', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3242', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3243', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3244', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3245', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3246', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3247', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3248', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3249', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3250', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3251', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3252', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'other)', '(_face', 'serious)', '(_prop', "'(hat", 'moustache', 'beard', '))\n']
# ['3253', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3254', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'black)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3255', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3256', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3257', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3258', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3259', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3260', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3261', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(hat", '))\n']
# ['3262', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3263', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3264', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(glasses", '))\n']
# ['3265', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3266', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3267', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3268', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3269', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3270', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3271', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3272', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3273', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3274', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3275', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3276', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3277', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3278', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'(glasses", '))\n']
# ['3279', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3280', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3281', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3282', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3283', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3284', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3285', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3286', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3287', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3288', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3289', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(hat", '))\n']
# ['3290', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3291', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3292', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3293', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3294', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3295', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3296', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3297', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3298', '(_sex', '', 'male)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3299', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3300', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3301', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3302', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3303', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3304', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(hat", '))\n']
# ['3305', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3306', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'(hat", '))\n']
# ['3307', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3308', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3309', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3310', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3311', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3312', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3313', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3314', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3315', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3316', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3317', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3318', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3319', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3320', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3321', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3322', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3323', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3324', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3325', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3326', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3327', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3328', '(_sex', '', 'female)', '(_age', '', 'senior)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3329', '(_sex', '', 'female)', '(_age', '', 'child)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(hat", '))\n']
# ['3330', '(_sex', '', 'male)', '(_age', '', 'child)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(hat", '))\n']
# ['3331', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3332', '(_sex', '', 'female)', '(_age', '', 'teen)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3333', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'other)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3334', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3335', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3336', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3337', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3338', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3339', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3340', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3341', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3342', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3343', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3344', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3345', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'black)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3346', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'black)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3347', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3348', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3349', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3350', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3351', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3352', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3353', '(_sex', '', 'male)', '(_age', '', 'teen)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3354', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3355', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3356', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3357', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3358', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3359', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3360', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3361', '(_sex', '', 'male)', '(_age', '', 'teen)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3362', '(_sex', '', 'male)', '(_age', '', 'child)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3363', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3364', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3365', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3366', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3367', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3368', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3369', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3370', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3371', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3372', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3373', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(moustache", 'beard', '))\n']
# ['3374', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3375', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3376', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3377', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3378', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3379', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3380', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3381', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3382', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3383', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3384', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3385', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3386', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3387', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3388', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3389', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3390', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3391', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3392', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3393', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3394', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3395', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3396', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3397', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3398', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3399', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3400', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3401', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3402', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3403', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3404', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3405', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3406', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3407', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3408', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3409', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3410', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3411', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3412', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3413', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3414', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3415', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3416', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3417', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3418', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3419', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3420', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3421', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3422', '(_sex', '', 'female)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'())\n"]
# ['3423', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'(glasses", 'moustache', '))\n']
# ['3424', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'(glasses", 'moustache', '))\n']
# ['3425', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'(glasses", 'moustache', '))\n']
# ['3426', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'smiling)', '(_prop', "'(glasses", 'moustache', '))\n']
# ['3427', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3428', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3429', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'funny)', '(_prop', "'())\n"]
# ['3430', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3431', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3432', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['3433', '(_sex', '', 'male)', '(_age', '', 'adult)', '(_race', 'white)', '(_face', 'serious)', '(_prop', "'())\n"]
# ['